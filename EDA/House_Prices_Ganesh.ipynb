# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option("display.max_rows",500)

# %%
train_df=pd.read_csv(r"H:\AI\librariesforAI\EDA\HousePrices\train.csv")
test_df=pd.read_csv(r"H:\AI\librariesforAI\EDA\HousePrices\test.csv")

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_df.duplicated().sum()
# Out:
# 0

# %%
train_df.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
train_df.drop(["Alley","Id","PoolQC","Fence","MiscFeature"],axis=1,inplace=True)

# %%
train_df.isna().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         8
# MasVnrArea         8
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinSF1         0
# BsmtFinType2      38
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         1
# 1stFlrSF           0
# 2ndFlrSF           0
# ...

# %%
for features in train_df.columns:
    if train_df[features].isnull().sum()>0:
        print("The column name",features,"has",train_df[features].isnull().sum(),"missing values")
# Out:
# The column name LotFrontage has 259 missing values
# The column name MasVnrType has 8 missing values
# The column name MasVnrArea has 8 missing values
# The column name BsmtQual has 37 missing values
# The column name BsmtCond has 37 missing values
# The column name BsmtExposure has 38 missing values
# The column name BsmtFinType1 has 37 missing values
# The column name BsmtFinType2 has 38 missing values
# The column name Electrical has 1 missing values
# The column name FireplaceQu has 690 missing values
# The column name GarageType has 81 missing values
# The column name GarageYrBlt has 81 missing values
# The column name GarageFinish has 81 missing values
# The column name GarageQual has 81 missing values
# The column name GarageCond has 81 missing values

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
train_df["LotFrontage"].value_counts()
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 64.0      19
# 24.0      19
# 73.0      18
# 55.0      17
# 63.0      17
# 79.0      17
# 72.0      17
# 100.0     16
# 66.0      15
# 74.0      15
# 51.0      15
# 52.0      14
# 59.0      13
# 82.0      12
# 71.0      12
# 67.0      12
# 43.0      12
# 40.0      12
# 57.0      12
# 76.0      11
# 69.0      11
# 92.0      10
# 34.0      10
# 53.0      10
# 86.0      10
# 88.0      10
# 84.0       9
# 35.0       9
# 62.0       9
# 44.0       9
# 77.0       9
# 93.0       8
# 98.0       8
# 96.0       8
# 61.0       8
# 95.0       7
# 58.0       7
# 120.0      7
# 107.0      7
# 94.0       6
# 81.0       6
# 36.0       6
# 30.0       6
# 48.0       6
# 91.0       6
# 41.0       6
# 54.0       6
# 89.0       6
# 110.0      6
# 105.0      6
# 32.0       5
# 47.0       5
# 87.0       5
# 56.0       5
# 37.0       5
# ...

# %%
def fill_values(data,fill_types,columns,data_frame):
    print("Missing Values BEFORE REMOVAL in ",data_frame," data")
    display(data.isnull().sum())
    for column in columns:
        if fill_types==1:
            data[column+"_random"]=data[column]
            random_sample = data[column].dropna().sample(data[column].isnull().sum(),random_state=0)
            random_sample.index=data[data[column].isnull()].index
            data.loc[data[column].isnull(),column+'_random']=random_sample
            data[column]=data[column+"_random"]
            data.drop([column+"_random"],axis=1,inplace=True)
        elif fill_types==2:
            data[column+'_NAN'] = np.where(data[column].isnull(),1,0)
            data[column].fillna(data[column].median(),inplace=True)
        elif fill_types==3:
            data[column].fillna(data[column].median(),inplace=True)
        elif fill_types==4:
            data[column].fillna(data[column].mode()[0],inplace=True)
    print("Missing Values AFTER REMOVAL in ",data_frame," data")
    display(data.isnull().sum())
    return(data)

# %%
fill_values(train_df,fill_types=1,columns=["LotFrontage","GarageYrBlt"],data_frame="HousePrice")
# Out:
# Missing Values BEFORE REMOVAL in  HousePrice  data
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         8
# MasVnrArea         8
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinSF1         0
# BsmtFinType2      38
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         1
# ...

# %%
def fill_values(data,fill_types,columns,data_frame):
    print("Missing Values BEFORE REMOVAL in ",data_frame," data")
    display(data.isnull().sum())
    for column in columns:
        if fill_types==1:
            data[column+"_random"]=data[column]
            random_sample = data[column].dropna().sample(data[column].isnull().sum(),random_state=0)
            random_sample.index=data[data[column].isnull()].index
            data.loc[data[column].isnull(),column+'_random']=random_sample
            data[column]=data[column+"_random"]
            data.drop([column+"_random"],axis=1,inplace=True)
        elif fill_types==2:
            data[column+'_NAN'] = np.where(data[column].isnull(),1,0)
            data[column].fillna(data[column].median(),inplace=True)
        elif fill_types==3:
            data[column].fillna(data[column].median(),inplace=True)
        elif fill_types==4:
            data[column].fillna(data[column].mode()[0],inplace=True)
    print("Missing Values AFTER REMOVAL in ",data_frame," data")
    display(data.isnull().sum())
    return(data)

# %%
fill_values(data=train_df,fill_types=4,columns=["MasVnrType","BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1","BsmtFinType2","Electrical","GarageType","GarageYrBlt","GarageFinish","GarageQual","GarageCond"],data_frame="HousePrice")
# Out:
# Missing Values BEFORE REMOVAL in  HousePrice  data
# MSSubClass         0
# MSZoning           0
# LotFrontage        0
# LotArea            0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         8
# MasVnrArea         8
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinSF1         0
# BsmtFinType2      38
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         1
# ...

# %%
fill_values(train_df,fill_types=1,columns=["MasVnrArea"],data_frame="HousePrice")
# Out:
# Missing Values BEFORE REMOVAL in  HousePrice  data
# MSSubClass         0
# MSZoning           0
# LotFrontage        0
# LotArea            0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         0
# MasVnrArea         8
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual           0
# BsmtCond           0
# BsmtExposure       0
# BsmtFinType1       0
# BsmtFinSF1         0
# BsmtFinType2       0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         0
# ...

# %%
train_df["FireplaceQu"].value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
train_df["FireplaceQu"]=train_df["FireplaceQu"].fillna("Others")

# %%
train_df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       8
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# ...

# %%
train_df["FireplaceQu"].value_counts()
# Out:
# Others    690
# Gd        380
# TA        313
# Fa         33
# Ex         24
# Po         20
# Name: FireplaceQu, dtype: int64

# %%
train_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub       FR2       Gtl  ...             0         0           0
# 2    AllPub    Inside       Gtl  ...             0         0           0
# 3    AllPub    Corner       Gtl  ...           272         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
train_df["MSZoning"].value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
updated_df=le.fit_transform(train_df["MSZoning"])

# %%
new_df=pd.DataFrame(updated_df,columns=["MSZoning"])

# %%
new1_df=pd.get_dummies(train_df['MSZoning'],drop_first=True)

# %%
train_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub       FR2       Gtl  ...             0         0           0
# 2    AllPub    Inside       Gtl  ...             0         0           0
# 3    AllPub    Corner       Gtl  ...           272         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
train_df=pd.concat([train_df,new1_df],axis=1)

# %%
train_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... MiscVal MoSold YrSold SaleType  \
# 0    AllPub    Inside       Gtl  ...       0      2   2008       WD
# 1    AllPub       FR2       Gtl  ...       0      5   2007       WD
# 2    AllPub    Inside       Gtl  ...       0      9   2008       WD
# 3    AllPub    Corner       Gtl  ...       0      2   2006       WD
# 4    AllPub       FR2       Gtl  ...       0     12   2008       WD
#
#   SaleCondition  SalePrice  FV  RH  RL RM
# 0        Normal     208500   0   0   1  0
# ...

# %%
train_df.drop("MSZoning",axis=1,inplace=True)

# %%
train_df.head()
# Out:
#    MSSubClass  LotFrontage  LotArea Street LotShape LandContour Utilities  \
# 0          60         65.0     8450   Pave      Reg         Lvl    AllPub
# 1          20         80.0     9600   Pave      Reg         Lvl    AllPub
# 2          60         68.0    11250   Pave      IR1         Lvl    AllPub
# 3          70         60.0     9550   Pave      IR1         Lvl    AllPub
# 4          60         84.0    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood  ... MiscVal MoSold YrSold SaleType  \
# 0    Inside       Gtl      CollgCr  ...       0      2   2008       WD
# 1       FR2       Gtl      Veenker  ...       0      5   2007       WD
# 2    Inside       Gtl      CollgCr  ...       0      9   2008       WD
# 3    Corner       Gtl      Crawfor  ...       0      2   2006       WD
# 4       FR2       Gtl      NoRidge  ...       0     12   2008       WD
#
#    SaleCondition  SalePrice  FV  RH RL RM
# 0         Normal     208500   0   0  1  0
# ...

# %%
train_df.isnull().sum()
# Out:
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       8
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le1=LabelEncoder()
updated1_df=le1.fit_transform(train_df["Street","LotShape","LandContour","Utilities"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\HP\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\HP\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\HP\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Street', 'LotShape', 'LandContour', 'Utilities')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
## Chechking the null cols
# for feature in train_df.columns:
#     if train_df[feature].isna().sum()>0:
#         print(feature)
